# %% [markdown]
# # Printing Hello World

# %%
print("Hello world")
# Out:
# Hello world

# %%
b="hello"
print(b)
# Out:
# hello

# %% [markdown]
# # List

# %%
a=[1,2,3,4,5]
print(type(a))
print(a[0])
print(a[4])

# %% [markdown]
# # Tuple

# %%
b=(2,3,4,5,6)
print(type(b))
print(b[1])
print(b[2])

# %% [markdown]
# # Set

# %%
c={1,2,3,4,4,5,5}
print(type(c))

# %% [markdown]
# # String

# %%
d="Hello"
print(type(d))
print(d[3])

# %% [markdown]
# # Dictionary

# %%
e={"name":"Ali" , "age":12}
print(type(e))
print(e["name"])
print(e["age"])
# Out:
# <class 'dict'>
# Ali
# 12

# %% [markdown]
# 1. First Item
# 2. Second Item
# 3. Third Item

# %% [markdown]
# **This is my first program**
