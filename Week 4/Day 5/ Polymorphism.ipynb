# %% [markdown]
# ## Polymorphism with Method Overriding

# %%
class Animal:
    def sound(self):
        print("Animal makes a sound")

class Dog(Animal):
    def sound(self):
        print("Dog barks")

class Cat(Animal):
    def sound(self):
        print("Cat meows")

# objects
d = Dog()
c = Cat()

d.sound()
c.sound()
# Out:
# Dog barks
# Cat meows

# %% [markdown]
# ## Polymorphism with Same Method in Different Classes

# %%
class Bird:
    def fly(self):
        print("Bird can fly")

class Airplane:
    def fly(self):
        print("Airplane can fly")

b = Bird()
a = Airplane()

b.fly()
a.fly()
# Out:
# Bird can fly
# Airplane can fly

# %% [markdown]
# ## Polymorphism with Functions

# %%
def add(x, y, z=0):
    return x + y + z

print(add(5, 3))
print(add(5, 3, 2))
# Out:
# 8
# 10
