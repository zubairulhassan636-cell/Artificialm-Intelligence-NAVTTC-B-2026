# %% [markdown]
# # Types of Errors

# %% [markdown]
# ## 1. Syntax Error

# %% [markdown]
# ## 2. Logical Error

# %% [markdown]
# ## 3. Runtime Error

# %% [markdown]
# ## 4. Time limit Exceeded Error

# %% [markdown]
# ## 5. Semantic Error

# %% [markdown]
# ## 6. Linker Error

# %% [markdown]
# ## 7. Resource Error

# %% [markdown]
# ## 8. Security Error
